# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import numpy as np

# %%
games_df = pd.read_csv('nba_game_details_cleaned.csv')
games_df.head(10)
# Out:
#     GAME_ID   GAME_DATE TEAM_away TEAM_home  TEAM_ID_away  TEAM_ID_home  \
# 0  21201219  2013-04-17       CLE       CHA    1610612739    1610612766
# 1  21201223  2013-04-17       UTA       MEM    1610612762    1610612763
# 2  21201226  2013-04-17       MIL       OKC    1610612749    1610612760
# 3  21201216  2013-04-17       BOS       TOR    1610612738    1610612761
# 4  21201227  2013-04-17       PHX       DEN    1610612756    1610612743
# 5  21201229  2013-04-17       LAC       SAC    1610612746    1610612758
# 6  21201224  2013-04-17       NOH       DAL    1610612740    1610612742
# 7  21201221  2013-04-17       PHI       IND    1610612755    1610612754
# 8  21201230  2013-04-17       GSW       POR    1610612744    1610612757
# 9  21201220  2013-04-17       ORL       MIA    1610612753    1610612748
#
#    FGM_away  FGM_home  FGA_away  FGA_home  ...  STL_home  BLK_away  BLK_home  \
# 0        39        37        80        73  ...         8         3         4
# ...

# %%
games_df.TEAM_home.value_counts()
# Out:
# PHX    400
# DAL    397
# SAC    396
# OKC    395
# HOU    395
# DEN    395
# IND    395
# UTA    395
# GSW    395
# CLE    395
# WAS    395
# LAL    394
# MIL    394
# ORL    394
# BOS    394
# PHI    394
# MEM    394
# SAS    394
# BKN    394
# MIA    394
# POR    394
# LAC    393
# CHI    393
# ATL    393
# NYK    392
# TOR    392
# MIN    391
# CHA    390
# DET    390
# NOP    353
# NOH     41
# Name: TEAM_home, dtype: int64

# %%
games_df.TEAM_ID_home.value_counts()
# Out:
# 1610612756    400
# 1610612742    397
# 1610612758    396
# 1610612764    395
# 1610612760    395
# 1610612762    395
# 1610612743    395
# 1610612754    395
# 1610612739    395
# 1610612744    395
# 1610612745    395
# 1610612763    394
# 1610612749    394
# 1610612740    394
# 1610612738    394
# 1610612759    394
# 1610612747    394
# 1610612755    394
# 1610612751    394
# 1610612748    394
# 1610612757    394
# 1610612753    394
# 1610612737    393
# 1610612746    393
# 1610612741    393
# 1610612752    392
# 1610612761    392
# 1610612750    391
# 1610612765    390
# 1610612766    390
# Name: TEAM_ID_home, dtype: int64

# %%
games_df.TEAM_ID_home.nunique()
# Out:
# 30

# %%
games_df.WIN_home.value_counts()
# Out:
# 1    6811
# 0    5010
# Name: WIN_home, dtype: int64

# %%
games_df.isna().sum()
# Out:
# GAME_ID         0
# GAME_DATE       0
# TEAM_away       0
# TEAM_home       0
# TEAM_ID_away    0
# TEAM_ID_home    0
# FGM_away        0
# FGM_home        0
# FGA_away        0
# FGA_home        0
# FG_PCT_away     0
# FG_PCT_home     0
# FG3_PCT_away    0
# FG3_PCT_home    0
# FTM_away        0
# FTM_home        0
# FTA_away        0
# FTA_home        0
# FT_PCT_away     0
# FT_PCT_home     0
# OREB_away       0
# OREB_home       0
# DREB_away       0
# DREB_home       0
# REB_away        0
# REB_home        0
# AST_away        0
# AST_home        0
# STL_away        0
# STL_home        0
# BLK_away        0
# BLK_home        0
# TOV_away        0
# TOV_home        0
# PF_away         0
# PF_home         0
# PTS_away        0
# PTS_home        0
# WIN_home        0
# dtype: int64

# %%
games_df = games_df.dropna()

games_df['TEAM_home'] = np.where(games_df['TEAM_home'] == 'NOH', 'NOP', games_df['TEAM_home'])
games_df['TEAM_away'] = np.where(games_df['TEAM_away'] == 'NOH', 'NOP', games_df['TEAM_away'])

games_df.head()
# Out:
#     GAME_ID   GAME_DATE TEAM_away TEAM_home  TEAM_ID_away  TEAM_ID_home  \
# 0  21201219  2013-04-17       CLE       CHA    1610612739    1610612766
# 1  21201223  2013-04-17       UTA       MEM    1610612762    1610612763
# 2  21201226  2013-04-17       MIL       OKC    1610612749    1610612760
# 3  21201216  2013-04-17       BOS       TOR    1610612738    1610612761
# 4  21201227  2013-04-17       PHX       DEN    1610612756    1610612743
#
#    FGM_away  FGM_home  FGA_away  FGA_home  ...  STL_home  BLK_away  BLK_home  \
# 0        39        37        80        73  ...         8         3         4
# 1        25        34        78        84  ...         7         6         8
# 2        36        37        85        89  ...         8         3         2
# 3        37        40        84        80  ...         5         2         5
# 4        40        49       104        93  ...         8         5         8
#
#    TOV_away  TOV_home  PF_away  PF_home  PTS_away  PTS_home  WIN_home
# ...

# %%
games_df.TEAM_away.value_counts()
# Out:
# LAC    398
# ORL    398
# TOR    397
# DEN    397
# POR    396
# MIL    396
# BOS    396
# DAL    396
# BKN    396
# MIA    396
# IND    395
# PHI    395
# SAS    395
# MEM    395
# UTA    395
# SAC    394
# LAL    394
# HOU    394
# WAS    394
# NOP    394
# DET    393
# OKC    393
# NYK    392
# MIN    392
# CHA    392
# ATL    391
# PHX    391
# CHI    390
# GSW    388
# CLE    388
# Name: TEAM_away, dtype: int64

# %%
df_corr = games_df.corr()
df_corr
# Out:
#                GAME_ID  TEAM_ID_away  TEAM_ID_home  FGM_away  FGM_home  \
# GAME_ID       1.000000      0.001600     -0.001711  0.283141  0.248231
# TEAM_ID_away  0.001600      1.000000     -0.045413 -0.032791 -0.015333
# TEAM_ID_home -0.001711     -0.045413      1.000000 -0.048983 -0.031265
# FGM_away      0.283141     -0.032791     -0.048983  1.000000  0.255094
# FGM_home      0.248231     -0.015333     -0.031265  0.255094  1.000000
# FGA_away      0.312558      0.009373     -0.053671  0.489738  0.280785
# FGA_home      0.308279     -0.050471     -0.016953  0.272989  0.472898
# FG_PCT_away   0.087841     -0.043725     -0.016853  0.766500  0.079264
# FG_PCT_home   0.047012      0.020116     -0.023911  0.083873  0.762270
# FG3_PCT_away  0.031124     -0.022370      0.017768  0.364993  0.035199
# FG3_PCT_home -0.000109      0.024046     -0.006948  0.024271  0.370702
# FTM_away      0.006167      0.014155      0.010114 -0.150203  0.113706
# ...

# %%
df_corr = games_df.corr()

# Drop fields
#'GAME_DATE', 'TEAM_away', 'TEAM_home',
fields = ['GAME_ID', 'TEAM_ID_away', 'TEAM_ID_home']
df_corr.drop(fields, inplace=True)
df_corr.drop(fields, axis=1, inplace=True)


df_corr
# Out:
#               FGM_away  FGM_home  FGA_away  FGA_home  FG_PCT_away  \
# FGM_away      1.000000  0.255094  0.489738  0.272989     0.766500
# FGM_home      0.255094  1.000000  0.280785  0.472898     0.079264
# FGA_away      0.489738  0.280785  1.000000  0.301635    -0.179304
# FGA_home      0.272989  0.472898  0.301635  1.000000     0.085712
# FG_PCT_away   0.766500  0.079264 -0.179304  0.085712     1.000000
# FG_PCT_home   0.083873  0.762270  0.092233 -0.204514     0.025025
# FG3_PCT_away  0.364993  0.035199 -0.108889  0.042059     0.494434
# FG3_PCT_home  0.024271  0.370702  0.038737 -0.120960    -0.002897
# FTM_away     -0.150203  0.113706 -0.184113  0.135379    -0.033823
# FTM_home      0.120342 -0.188737  0.125146 -0.207523     0.044567
# FTA_away     -0.172561  0.107737 -0.194934  0.131513    -0.050909
# FTA_home      0.108149 -0.200138  0.124315 -0.213717     0.031848
# FT_PCT_away   0.033715  0.028046 -0.002400  0.029511     0.038853
# ...

# %%
np.ones_like(df_corr, dtype=np.bool)
# Out:
# C:\Users\Ryan\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   """Entry point for launching an IPython kernel.
# array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]])

# %%
mask = np.triu(np.ones_like(df_corr, dtype=np.bool))
# Out:
# C:\Users\Ryan\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   """Entry point for launching an IPython kernel.

# %%
fig, ax = plt.subplots(figsize=(10, 8))
# mask
mask = np.triu(np.ones_like(df_corr, dtype=np.bool))
# adjust mask and df
mask = mask[1:, :-1]
corr = df_corr.iloc[1:,:-1].copy()
# plot heatmap
sb.heatmap(corr, mask=mask, annot=True, fmt=".2f", cmap='Blues',
           vmin=-1, vmax=1, cbar_kws={"shrink": .8})
# yticks
plt.yticks(rotation=0)
plt.show()
# Out:
# C:\Users\Ryan\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
fig, ax = plt.subplots(figsize=(24,20))

# mask
mask = np.triu(np.ones_like(df_corr, dtype=np.bool))
# adjust mask and df
mask = mask[1:, :-1]
corr = df_corr.iloc[1:,:-1].copy()
# color map
cmap = sb.diverging_palette(0, 230, 90, 60, as_cmap=True)
# plot heatmap
sb.heatmap(corr, mask=mask, annot=True, fmt=".2f", 
           linewidths=5, cmap=cmap, vmin=-1, vmax=1, 
           cbar_kws={"shrink": .8}, square=True)
# ticks
yticks = [i.upper() for i in corr.index]
xticks = [i.upper() for i in corr.columns]
plt.yticks(plt.yticks()[0], labels=yticks, rotation=0)
plt.xticks(plt.xticks()[0], labels=xticks)
# title and background
fig.patch.set_facecolor('white')
title = 'CORRELATION MATRIX\nNBA Team Stats\n'
plt.title(title, loc='left', fontsize=18)
plt.savefig('corr_matrix.png', facecolor=fig.get_facecolor(), edgecolor='none', dpi=100, transparent=False)
# Out:
# C:\Users\Ryan\anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   after removing the cwd from sys.path.

# %% [markdown]
# ##
